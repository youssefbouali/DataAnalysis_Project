# %% [markdown]
# ## Import libraries

# %% [markdown]
# Libraries

# %%
import asyncio
import json
from datetime import datetime
from forex_python.converter import CurrencyRates
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import pandas as pd
import re
import requests
from rapidfuzz import fuzz
from urllib.parse import urljoin

# %% [markdown]
# # Normalise une chaîne de caractères en la convertissant en minuscule.
# Si le texte n'est pas une chaîne, il est converti en chaîne ou retourné vide.

# %%
# Function to normalize text
def normalize_text(text):
    if isinstance(text, str):
        text = text.lower()  # Convert to lowercase
        # nom = re.sub(r'[^a-z\s]', '', text)  # Uncomment if needed for special character removal
        return text
    else:
        # Convert non-string inputs to a string or handle them appropriately
        return str(text) if text is not None else ""

# %% [markdown]
# # Compare un nom à une liste de noms et retourne ceux qui ont une similarité supérieure à un seuil.
# Utilise l'algorithme RapidFuzz pour calculer le score de similarité.

# %%
# Function to find similar noms using RapidFuzz
def find_similar_noms(nom, nom_list, threshold=95):
    similar_noms = []
    for other_nom in nom_list:
        score = fuzz.ratio(nom, other_nom)
        if score >= threshold:
            similar_noms.append((nom, other_nom, score))
    return similar_noms

# %%
# Configure caching options
options = Options()
#options.add_argument("--headless")  # Run in headless mode (without opening a window)

options.page_load_strategy = 'eager'

#options.add_argument("--disable-gpu")
options.add_argument("--no-sandbox")
options.add_argument("--enable-unsafe-swiftshader")  # Disable GPU hardware acceleration

options.add_argument("--disable-extensions")
options.add_argument("--disable-dev-shm-usage")
options.add_argument("--disable-software-rasterizer")  # Disable the software rasterizer
options.add_argument("--disable-blink-features=AutomationControlled")
options.add_experimental_option("prefs", {
    "profile.managed_default_content_settings.images": 2,  # Block images
    "profile.managed_default_content_settings.stylesheets": 2,  # Block CSS
    "profile.managed_default_content_settings.fonts": 2,  # Block fonts
    "profile.managed_default_content_settings.plugins": 2,  # Block plugins
    "profile.managed_default_content_settings.popups": 2,  # Block popups
    "profile.managed_default_content_settings.notifications": 2,  # Block notifications
    "profile.managed_default_content_settings.media_stream": 2,  # Block audio and video
})
options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36")

# %%
with open('platformes.json', 'r') as file:
    sites = json.load(file)

# %% [markdown]
# Initialise le WebDriver de Selenium avec des options configurées pour améliorer les performances
#     et éviter la détection des bots.

# %%
# Initialize the WebDriver with the options
def initialize_driver():
    driver = webdriver.Chrome(options=options)
    return driver

# %%
# Headers to mimic a real browser and avoid bot detection
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36",
    "Accept-Language": "en-US,en;q=0.9",
    "Accept-Encoding": "gzip, deflate, br",
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,*/*;q=0.8',
    'Referer': 'https://www.google.com/',
    "Connection": "keep-alive",
    "Upgrade-Insecure-Requests": "1",
    "TE": "Trailers"
}

date_now = datetime.now().strftime('%Y-%m-%d %H:%M:%S')

# %% [markdown]
# Convertit un prix donné en USD à partir d'une chaîne de caractères contenant une devise détectée.
#     Si aucune devise n'est détectée, une tentative de conversion est effectuée à partir des symboles trouvés.

# %%
currency_converter = CurrencyRates()
def convert_prix(the_prix, detected_currency="UNKNOWN"):
    # Convert prix to USD if necessary
    try:
        # Detect currency from the prix string
        if detected_currency == "UNKNOWN":
            if "USD" in the_prix or "$" in the_prix:
                detected_currency = "USD"
            elif "EUR" in the_prix or "€" in the_prix:
                detected_currency = "EUR"

        # Clean the prix string by removing currency symbols and unnecessary text
        cleaned_prix = (
            the_prix
            .replace("USD", "")
            .replace("current price: ", "")
            .replace("$", "")
            .replace("EUR", "")
            .replace("€", "")
            .replace("\xa0", "")
            .replace("–", "")
            .replace(",", "")
            .strip()
        )

        # Convert the cleaned string to a float
        try:
            cleaned_prix = next(float(part) for part in cleaned_prix.split() if part.replace('.', '', 1).isdigit())
        except StopIteration:
            return None  # Return None if no float is found

        # Convert EUR to USD if necessary
        if detected_currency == "EUR":
            cleaned_prix = currency_converter.convert("EUR", "USD", cleaned_prix)
            print(f"Converted prix: {cleaned_prix} USD")
        
        return cleaned_prix
        
    except Exception as e:
        print(f"Currency detection or conversion error: {e}")

# %% [markdown]
# Récupère la description d'un produit à partir de la page web d'un site donné,
#     en utilisant le sélecteur CSS fourni.

# %%
async def get_description(driver, site):
    try:
        # Navigate to the product page
        driver.get(site["url"])

        html_content = driver.page_source

        # Parse the HTML with BeautifulSoup
        soup = BeautifulSoup(html_content, "html.parser")

        # Extract the description using the provided CSS selector
        description_element = soup.select_one(site["description"])
        description = description_element.get_text(separator=' ', strip=True) if description_element else ""

        return description, description_element
    except Exception as e:
        print(f"Error fetching description for {site['url']}: {e}")
        return "", None

# %% [markdown]
# Collecte les données de produits à partir d'un site web en utilisant les sélecteurs CSS définis.
#     Peut parcourir plusieurs pages si un sélecteur de page suivante est disponible.

# %%
def extract_characteristics(soup, site_config):
    # Parse the HTML content
    #soup = BeautifulSoup(html, 'html.parser')
    
    result = {}

    # Loop through each site in the config
    for section_name, section_config in site_config['sections'].items():
        # Select the section based on sectionSelector
        section = soup.select_one(section_config['sectionSelector'])
        if not section:
            continue

        if section:
            # For sites like BlueStar, get the section name (only if 'nameSelector' exists)
            section_heading = None
            if 'nameSelector' in section_config:
                section_heading = section.select_one(section_config['nameSelector'])
                section_heading = section_heading.get_text(strip=True) if section_heading else None

            # Initialize result for this section
            if section_heading:
                if section_heading not in result:
                    result[section_heading] = {}
            else:
                if section_name not in result:
                    result[section_name] = {}

            # Extract rows from the section
            rows = section.select(section_config['rowsSelector'])
            for row in rows:
                if section_config['specNameSelector']:
                    spec_name = row.select_one(section_config['specNameSelector'])
                    spec_value = row.select_one(section_config['specValueSelector'])

                    if spec_name and spec_value:
                        spec_name = spec_name.get_text(strip=True)
                        spec_value = spec_value.get_text(strip=True)

                        # Handle <br> tags for certain sites
                        if spec_value and '<br' in spec_value:
                            spec_value = spec_value.replace('<br>', ', ').replace('<br/>', ', ').replace('<br />', ', ')

                        if section_heading:
                            result[section_heading][spec_name] = spec_value
                        else:
                            result[section_name][spec_name] = spec_value
                else:
                    # For sites with no specNameSelector, directly store the list items as features (strings)
                    feature = row.get_text(strip=True)
                    if feature:
                        # Ensure result[section_name] is a list
                        if section_name not in result:
                            result[section_name] = []
                        elif not isinstance(result[section_name], list):
                            result[section_name] = [result[section_name]]  # Convert to list if it's a dict

                        result[section_name].append(feature)

            dimensions_text = section.get_text(strip=True)
            if 'Approximate Dimensions' in dimensions_text:
                # Use regex to find height and width
                height_match = re.search(r'Height:\s*(\d+[\d/]*\s?[a-zA-Z]*)', dimensions_text)
                width_match = re.search(r'Width:\s*(\d+[\d/]*\s?[a-zA-Z]*)', dimensions_text)

                # If matches are found, store them in the result
                if height_match:
                    result['SPECIFICATIONS'] = result.get('DIMENSIONS', {})
                    result['SPECIFICATIONS']['Height'] = height_match.group(1)
                if width_match:
                    result['SPECIFICATIONS'] = result.get('DIMENSIONS', {})
                    result['SPECIFICATIONS']['Width'] = width_match.group(1)

    # Normalize the extracted characteristics before returning
    return result


# Define the normalization mapping
normalized_names = {
    'Height': [
        'Product Height', 
        'Height To Top Of Refrigerator (Without Hinges)', 
        'Height To Top Of Door Hinge',
        'Maximum Height', 
        'Minimum Height'
    ],
    'Width': [
        'Product Width',
        'Width',
        'Width :',
        'Cutout Dimensions:',
        'Shipping Width :',
        'Shipping Depth :'
    ],
    'Depth': [
        'Depth Without Handle', 
        'Depth With Handle', 
        'Depth with Door Closed :', 
        'Shipping Depth :'
    ],
    'Finish': ['Finish', 'Fingerprint Resistant', 'Color Appearance'],
    'Material': ['Tub Material', 'Handle Color'],
    'Control Panel Location': ['Control Panel Location', 'Type of Control'],
    'Noise Level': ['Noise Level'],
    'Energy Rating': ['ENERGY STAR® Rated'],
    'Voltage': ['Voltage', 'Voltage :'],
    'Capacity': ['Total Place Settings', 'Freezer Capacity', 'Overall Capacity', 'Refrigerator Capacity'],
    'Rack Features': ['Height Adjustable Upper Rack', 'Lower Rack'],
    'Child Lock': ['Child Lock'],
    'Water Consumption': ['Water Consumption Per Cycle'],
    'Energy Consumption': ['Energy Consumption (kWh / Year)'],
    'Cycle Options': ['Number of Wash Cycles', 'Number of Options'],
    'Sprayers': ['Number of Sprayers'],
    'Warranty': ['Parts', 'Labor'],
    'Weight': ['Product Weight / Shipping Weight', 'Weight'],
}


def normalize_name(raw_name):
    """Normalize the specification name based on the mapping."""
    for normalized, aliases in normalized_names.items():
        if raw_name in aliases:
            return normalized
    return raw_name  # Return as-is if no match is found


def normalize_characteristics(characteristics):
    """Normalize the specification dictionary keys across multiple sites."""
    normalized_characteristics = {}
    
    for category, data in characteristics.items():
        if isinstance(data, dict):
            # Normalize specifications in this category
            normalized_category = {}
            for spec_name, spec_value in data.items():
                normalized_name = normalize_name(spec_name)
                
                # If the normalized name already exists, append the new value to a list
                if normalized_name in normalized_category:
                    if not isinstance(normalized_category[normalized_name], list):
                        normalized_category[normalized_name] = [normalized_category[normalized_name]]
                    normalized_category[normalized_name].append(spec_value)
                else:
                    normalized_category[normalized_name] = spec_value
            normalized_characteristics[category] = normalized_category
        elif isinstance(data, list):
            # Handle the list case, just store as-is
            normalized_characteristics[category] = data
        else:
            normalized_characteristics[category] = data
    
    return normalized_characteristics




def sort_json_by_key(characteristics):
    """Sort the JSON dictionary by keys (a->z)."""
    if isinstance(characteristics, dict):
        return {k: sort_json_by_key(v) if isinstance(v, dict) else v for k, v in sorted(characteristics.items())}
    elif isinstance(characteristics, list):
        return [sort_json_by_key(item) for item in characteristics]
    return characteristics


def json_to_text(data, parent_key=""):
    data = sort_json_by_key(data)
    result = ""
    
    for key, value in data.items():
        # Construct the full key path if there's a parent key
        full_key = f"{key}" if parent_key else key
        
        if isinstance(value, dict):
            # If the value is a dictionary, recurse with the updated key
            result += json_to_text(value, full_key)
        else:
            # Append the key-value pair to the result
            result += f"{full_key}: {value}, "
    
    return result

# %%
# site category
async def collect_data_from_scraping(driver, site, products=None, page_limit=2, max_products=30, current_page=1, total_products=0):
    try:
        driver.get(site["url"])
    except Exception as e:
        print(f"Error loading {site['url']}: {e}")
        return None

    # Retrieve HTML content asynchronously
    html_content = await asyncio.to_thread(lambda: driver.page_source)

    print("Opened : ", site["url"])
    soup = BeautifulSoup(html_content, "html.parser")

    if products is None:
        products = []

    tasks = []
    
    for item in soup.select(site["product_selector"]):
        if total_products >= max_products:
            break  # Stop when max products are reached
        tasks.append(process_product(driver, item, site))
        total_products += 1
    
    # Run all product processing tasks concurrently
    pts = await asyncio.gather(*tasks)
    for product in pts:
        products.append(product)
            
    #dftemp = pd.DataFrame(products)
    #export_data(dftemp, "tempElectromenagerscleaned_data")

    if site.get("next_page") and current_page <= page_limit:
        print ("next_page : ", current_page+1)
        next_page = soup.select_one(site["next_page"])
        if next_page and 'href' in next_page.attrs:
            next_page_url = next_page['href']
            if next_page_url.startswith('/'):
                next_page_url = urljoin(site["url"], next_page_url)  # Automatically combines domain with path
            print(next_page_url)
            site["url"] = next_page_url
            current_page += 1  # Increment the page counter
            await collect_data_from_scraping(driver, site, products, page_limit, max_products, current_page) #total_products if total in all pages

    
    if products:
        # Read old data and clean current data
        try:
            # Attempt to read the file
            old_data = pd.read_csv("temp2Electromenagerscleaned_data.csv")
        except FileNotFoundError:
            # If the file doesn't exist, initialize as an empty DataFrame
            old_data = pd.DataFrame()
            
        newproducts = pd.DataFrame(products)
    
        data_now = pd.concat([old_data, newproducts], ignore_index=True)
        df_cleaned = clean_data(data_now)
        try:
            df_cleaned = clean_data(data_now)
            export_data(df_cleaned, "temp2Electromenagerscleaned_data")
            print("Appended site:", site["url"])  # Log the last processed site
        except Exception as e:
            print(f"Error during cleaning or exporting data for site {site['url']}: {e}")
    else:
        print("No products found for site:", site["url"])

    return products

# %% [markdown]
# Extrait les informations d'un produit (nom, prix, promotion, etc.) à partir des sélecteurs définis,
#     et récupère sa description si possible.

# %%
async def process_product(driver, item, site):
    nom = item.select_one(site["nom_selector"])
    prix = item.select_one(site["prix_selector"])
    promotion = item.select_one(site["promotion_selector"]) if site.get("promotion_selector") else None

    product = {}

    if nom and prix:
        the_prix = prix.text.strip()
        detected_currency = "UNKNOWN"
        cleaned_prix = convert_prix(the_prix, detected_currency)

        promotion_text = promotion.text.strip() if promotion else ""
        nomt = nom.text.strip() if nom else None

        #if site.get("nom_regex"):
        #    nomt = nomt.str.extract(site["nom_regex"])

        product_url = ""
        if 'href' in nom.attrs:
            product_url = nom['href']
            if product_url.startswith('/'):
                product_url = urljoin(site["url"], product_url)  # Combine domain with path

        # Run description fetching concurrently
        if site.get("description"):
            description, soup = await get_description(driver, {"url": product_url, "description": site["description"]})
        else:
            description = None
            soup = None

        product = {
                "nom": nomt,
                "prix": cleaned_prix,
                "website": site["website"],
                "source": site["url"],
                "date_scraped": date_now,
                "category": site["category"],
                "promotion": promotion_text,
                "url": product_url,
                "description": description,
                "html": soup,
            }
        print("append product : ", nomt)
    return product

# %% [markdown]
# Collecte les données de produits à partir d'une API, en effectuant une requête GET
#     et en extrayant les données selon les clés fournies dans la configuration.

# %%
# Function to collect data from API
async def collect_data_from_api(site):
    response = await loop.run_in_executor(None, requests.get, site["url"])  # Asynchronous request

    if response.status_code == 200:
        data = response.json()
        products = []
        items = data.get(*site["selectors"]["product_key"].split('.'))

        for item in items:
            nom = item.get(site["selectors"]["nom_key"])
            prix = item.get(site["selectors"]["price_key"])
            category = item.get(site["selectors"]["category_key"])
            promotion = item.get(site["selectors"]["promotion_key"])

            if nom and prix:
                cleaned_prix = convert_prix(prix)
                products.append({
                    "nom": nom,
                    "prix": prix,
                    "website": site["website"],
                    "source": site["url"],
                    "date_scraped": date_now,
                    "category": category,
                    "promotion": promotion
                })
                print ("append : ",nom)

        return products
    else:
        print(f"API error: {response.status_code}")
        return []

# %%
# Function to collect all data concurrently
async def collect_all_data():
    data = []
    driver = initialize_driver()
    
    # Running scraping tasks concurrently
    tasks = []
    for site in sites:
        if site["type"] == "scraping":
            result = await collect_data_from_scraping(driver, site)
            if result:  # Check if result is not None or empty
                data.extend(result)
                print ("Add : ",site["url"])
        elif site["type"] == "API":
            result = await collect_data_from_api(site)
            if result:  # Check if result is not None or empty
                data.extend(result)
    
    driver.quit()  # Close the driver after all scraping is done
    return data

# %%
# Data cleaning function
def clean_data(raw_data):
    df = pd.DataFrame(raw_data)

    if 'nom' not in df.columns:
        print("Error: 'nom' column is missing!")
        return df

    df["nom"] = df["nom"].astype(str).str.replace(r"[,-]$|\(\)$|(?: - |, )?(Matte Black|Copper|Slate|Brown|biscuit|Champagne|Tuscan stainless steel|Brushed Black|Brushed Navy|Carbon Graphite|Chrome|Forest Green|Graphite Steel|Ivory|Alpine White|Grey|Sapphire Blue|Specialty|Dark Steel|Essence White|Midnight Steel|Mirror|Satin Green|Silver Steel|Titanium|Beige & Bisque|Metallic|Red|Specialty|Black Slate|Black slate|Black Stainless|Multi-color|Black steel|Bronze|Nickel|Diamond Gray|Platinum Glass|Platinum|Graphite Steel|Graphite steel|Green|Orange|Yellow|Stainless steel look|Black stainless steel|Bisque|CleanSteel|Black Glass|Graphite|Slate|Matte Black|Matte black|Custom Panel Ready|Custom Panel Required|Custom Panel|Stainless Steel|SmudgeProof Stainless Steel|Smudge Proof Stainless Steel|White Glass|PrintShield Black Stainless Steel|Stainless Steel with Brushed Stainless Steel Handles|Stainless Steel|Stainless steel|Stainless Look|Matte Black with Brushed Stainless Steel Handles and Knobs|High Gloss White|White|Matte White|Matte white|Starlight|Space|Black|Blue|Gold|Gray|Green|Purple|Pink|Silver|Fingerprint Resistant Black Stainless Steel|Fingerprint Resistant Stainless Steel)", "", regex=True)
        
    df['normalized_nom'] = df['nom'].apply(normalize_text)
    df['normalized_description'] = df['description'].apply(lambda x: normalize_text(x) if pd.notna(x) else "")
    
    df['nom_and_description'] = df['normalized_nom']+" "+df['normalized_description']
    
    df = df.drop_duplicates(subset=["normalized_nom", "website", "date_scraped"], keep="first")
    
    df_cleaned = df
    try:
        # Continue with finding similar noms and further processing...
        groups = []
        seen = set()

        # To store the similar rows with their corresponding similarity ratio
        similar_rows_info = []

        for idx, row in df.iterrows():
            if idx in seen:
                continue
            nom = row["nom_and_description"]
            matches = find_similar_noms(nom, df["nom_and_description"].tolist())
            
            if not matches:
                continue
            
            match_indices = [
                idx for idx, match in enumerate(df["nom_and_description"]) if (nom, match, fuzz.ratio(nom, match)) in matches
            ]
            
            if match_indices:
                groups.append(match_indices)
                seen.update(match_indices)
                
                # Store the similar rows and their ratios
                for match_idx in match_indices:
                    similarity_ratio = fuzz.ratio(nom, df["nom_and_description"].iloc[match_idx])
                    similar_rows_info.append((df.iloc[match_idx], similarity_ratio))

        rows_to_keep = set()
        for group in groups:
            if group:
                min_prix_index = df.loc[group, "prix"].idxmin()
                rows_to_keep.add(min_prix_index)

        # Convert rows_to_keep to a list
        rows_to_keep = list(rows_to_keep)

        # Get the rows that were removed
        rows_removed = set(df.index) - set(rows_to_keep)

        # Convert rows_removed to a list before using it as an indexer
        rows_removed_list = list(rows_removed)

        # Print the removed rows
        print("Removed rows:")
        print(df.loc[rows_removed_list])

        # Print the similar rows that were kept, along with their similarity ratios
        #print("\nSimilar rows kept (with similarity ratio):")
        #for row, ratio in similar_rows_info:
        #    print(f"Row: {row.to_dict()} - Similarity Ratio: {ratio}%")
        
        # Use the list as the indexer
        df_cleaned = df.loc[rows_to_keep].reset_index(drop=True)
    except KeyError as e:
        print(f"Erreur : {e}")
    #df = df.drop(columns=['nom_and_description'])
    
    return df_cleaned

# %%
# Export cleaned data
def export_data(df, filename="Electromenagerscleaned_data"):
    df.to_csv(filename+".csv", index=False)
    df.to_excel(filename+".xlsx", index=False, engine="openpyxl")
    print(f"Data exported to '{filename}'")

# %%
# Main execution
if __name__ == "__main__":
    # Get the event loop
    #raw_data = asyncio.run(collect_all_data())   not working with jupyter
    raw_data = await collect_all_data()


    df_cleaned = clean_data(raw_data)



    def get_site_config(website_name):
        for site in sites:
            if site['website'] == website_name:
                return site
        return None


    # Apply the function to the DataFrame
    df_cleaned['characteristics'] = df_cleaned.apply(
        lambda row: normalize_characteristics(extract_characteristics(row['html'], get_site_config(row['website']))) 
        if isinstance(row['html'], str) and row['html'].strip() 
        else {}, 
        axis=1
    )


    df_cleaned['text_characteristics'] = df_cleaned['characteristics'].apply(json_to_text)






    # Create or update columns dynamically
    #for index, row in df.iterrows():
    #    characteristics = row['characteristics']
    #    if not isinstance(characteristics, dict):
    #        continue
    #    
    #    for category, data in characteristics.items():
    #        if isinstance(data, dict):  # For nested dictionaries
    #            for spec_name, spec_value in data.items():
    #                column_name = f"charac_{spec_name}"
    #                if column_name in df.columns:
    #                    df.at[index, column_name] = spec_value
    #                else:
    #                    df[column_name] = None  # Initialize the column if it doesn't exist
    #                    df.at[index, column_name] = spec_value
    #        else:  # For simple values or lists
    #            if category in df.columns:
    #                df.at[index, category] = data
    #            else:
    #                df[category] = None  # Initialize the column if it doesn't exist
    #                df.at[index, category] = data
    

    try:
        old_data = pd.read_csv("Electromenagerscleaned_data.csv")
        data_now = pd.concat([old_data, df_cleaned], ignore_index=True)
    except FileNotFoundError:
        data_now = df_cleaned

    export_data(data_now)
    print("\r\nEnd..")
# Out:
# Opened :  https://www.bestbuy.com/site/refrigerators/all-refrigerators/pcmcat367400050001.c?id=pcmcat367400050001&intl=nosplash
# append product :  Insignia™ - 18 Cu. Ft. Top-Freezer Refrigerator with ENERGY STAR Certification - Stainless Steel
# append product :  Whirlpool - 28.4 Cu. Ft. Side-by-Side Refrigerator with In-Door-Ice Storage - Stainless Steel
# append product :  Insignia™ - 18.6 Cu. Ft. Bottom Freezer Refrigerator with ENERGY STAR Certification - Stainless Steel
# append product :  LG - Counter-Depth MAX 25.5 Cu. Ft. French Door Smart Refrigerator with Mirror InstaView - Stainless Steel
# append product :  Whirlpool - 20.5 Cu. Ft. Top-Freezer Refrigerator - Stainless Steel
# append product :  Insignia™ - 18 Cu. Ft. Top-Freezer Refrigerator with Handles - White
# append product :  Frigidaire - 17.6 Cu. Ft. Counter-Depth French Door Refrigerator - Stainless Steel
# append product :  LG - Standard Depth MAX 25.1 Cu. Ft. French Door Smart Refrigerator with Hybrid Handle - Stainless Steel
# append product :  Samsung - 18 Cu. Ft. Top Freezer Smart Refrigerator with All-Around Cooling - Stainless Steel
# append product :  Samsung - 27.4 cu. ft. Side-by-Side Refrigerator with Large Capacity - Stainless Steel
# append product :  Frigidaire - 20.5 Cu. Ft. Top-Freezer Refrigerator - Black
# append product :  Samsung - 15.6 cu. ft. Top Freezer Refrigerator with All-Around Cooling - Stainless Steel
# append product :  LG - Standard-Depth MAX 28.6 Cu. Ft. 4-Door French Door Smart Refrigerator with Full-Convert Drawer - Stainless Steel
# append product :  Whirlpool - 19.2 Cu. Ft. French Door Refrigerator with Freezer-to-Fridge Zone - Stainless Steel
# append product :  LG - 22.5 Cu. Ft. 4-Door French Door-in-Door Counter-Depth Smart Refrigerator with Craft Ice - Black Stainless Steel
# append product :  Insignia™ - 11.5 Cu. Ft. Bottom Mount Refrigerator with ENERGY STAR Certification - Stainless Steel
# append product :  Frigidaire - 25.6 Cu. Ft. Side-by-Side Refrigerator - Silver
# append product :  Whirlpool - 24.6 Cu. Ft. Side-by-Side Refrigerator - Stainless Steel
# next_page :  2
# https://www.bestbuy.com/site/searchpage.jsp?_dyncharset=UTF-8&browsedCategory=pcmcat367400050001&cp=2&id=pcat17071&iht=n&ks=960&list=y&sc=Global&st=categoryid%24pcmcat367400050001&type=page&usc=All%20Categories
# Opened :  https://www.bestbuy.com/site/searchpage.jsp?_dyncharset=UTF-8&browsedCategory=pcmcat367400050001&cp=2&id=pcat17071&iht=n&ks=960&list=y&sc=Global&st=categoryid%24pcmcat367400050001&type=page&usc=All%20Categories
# append product :  LG - 27.7 Cu. Ft. French Door Smart Refrigerator with External Ice and Water - Stainless Steel
# append product :  Insignia™ - 17 Cu. Ft. Garage Ready Convertible Upright Freezer with ENERGY STAR Certification - White
# append product :  Insignia™ - 14.2 Cu. Ft. Top-Freezer Refrigerator with ENERGY STAR Certification - White
# append product :  LG - 23.8 Cu. Ft. Top Freezer Refrigerator with Internal Water Dispenser - Stainless Steel
# append product :  Insignia™ - 10 Cu. Ft. Top-Freezer Refrigerator with Reversible Door and ENERGY STAR Certification - White
# append product :  Samsung - BESPOKE 23 cu. ft. 4-Door French Door Counter Depth Smart Refrigerator with Beverage Center - Stainless Steel
# append product :  Frigidaire - 22.3 Cu. Ft. Side-by-Side Counter-Depth Refrigerator - Silver
# append product :  Whirlpool - 19.4 Cu. Ft. 4-Door French Door Counter-Depth Refrigerator with Flexible Organization Spaces - Stainless Steel
# append product :  Frigidaire - Gallery 20.0 Cu. Ft. French Door Standard-Depth Refrigerator - Stainless Steel
# append product :  Whirlpool - 21.9 Cu. Ft. Bottom-Freezer Refrigerator - Stainless Steel
# append product :  LG - 27.8 Cu. Ft. 4-Door French Door Smart Refrigerator with Smart Cooling System - Stainless Steel
# append product :  LG - 27.7 Cu. Ft. French Door Smart Refrigerator with External Ice and Water - Black Stainless Steel
# append product :  Frigidaire - 11.5 Cu. Ft. Bottom-Freezer Refrigerator - Brushed Steel
# append product :  LG - 27 Cu. Ft. Side-by-Side Smart Refrigerator with Craft Ice - Black Stainless Steel
# append product :  Insignia™ - 20.5 Cu. Ft. Top-Freezer Refrigerator with ENERGY STAR Certification - Stainless Steel
# append product :  LG - 27.7 Cu. Ft. French Door Smart Refrigerator with External Ice and Water - Stainless Steel
# append product :  KitchenAid - 25.8 Cu. Ft. 5-Door French Door Refrigerator - Stainless Steel
# append product :  Samsung - BESPOKE Side-by-Side Counter Depth Smart Refrigerator with Beverage Center - Stainless Steel
# append product :  Frigidaire - 4.5 Cu. Ft. Mini Fridge - Silver
# next_page :  3
# https://www.bestbuy.com/site/searchpage.jsp?_dyncharset=UTF-8&browsedCategory=pcmcat367400050001&cp=3&id=pcat17071&iht=n&ks=960&list=y&sc=Global&st=categoryid%24pcmcat367400050001&type=page&usc=All%20Categories
# Opened :  https://www.bestbuy.com/site/searchpage.jsp?_dyncharset=UTF-8&browsedCategory=pcmcat367400050001&cp=3&id=pcat17071&iht=n&ks=960&list=y&sc=Global&st=categoryid%24pcmcat367400050001&type=page&usc=All%20Categories
# append product :  LG - 27 Cu. Ft. Side-by-Side Smart Refrigerator with Craft Ice - Stainless Steel
# append product :  Samsung - 27 cu. ft. 3-Door French Door Counter Depth Smart Refrigerator with Dual Auto Ice Maker - Fingerprint Resistant Stainless Look
# append product :  Whirlpool - 25.1 Cu. Ft. Side-by-Side Refrigerator - Stainless Steel
# append product :  Frigidaire - Gallery 21.5 Cu. Ft.  4-Door French Door Counter-Depth Refrigerator - Stainless Steel
# append product :  Samsung - 26 cu. ft. French Door Counter Depth Smart Refrigerator with Four Types of Ice - Stainless Steel
# append product :  Frigidaire - 22.3 Cu. Ft. Side-by-Side Refrigerator - Black Stainless Steel
# append product :  Whirlpool - 21.4 Cu. Ft. Side-by-Side Refrigerator with Fingerprint Resistant - Stainless Steel
# append product :  Samsung - 22 cu. ft. 3-Door French Door Smart Refrigerator with External Water Dispenser - Stainless Steel
# append product :  LG - 17.5 Cu. Ft. Garage Ready Top-Freezer Refrigerator with Reversible Doors - Stainless Steel
# append product :  Frigidaire - 13.9 Cu. Ft. Top-Freezer Refrigerator - Black
# append product :  LG - Counter-Depth MAX 26.5 Cu. Ft. French Door Smart Refrigerator with Internal Water - Stainless Steel
# append product :  LG - Counter-Depth MAX 25.5 Cu. Ft. French Door Smart Refrigerator with Four Kinds of Ice - Stainless Steel
# append product :  LG - 29.5 Cu. Ft. 4-Door French Door-in-Door Smart Refrigerator with Craft Ice - Stainless Steel
# append product :  Frigidaire 28.8 Cu. Ft. French Door Standard-Depth Refrigerator - Stainless Steel
# append product :  LG - 21.8 Cu. Ft. French Door Refrigerator with External Water Dispenser - Stainless Steel
# append product :  Samsung - BESPOKE 30 cu. ft. 3-Door French Door Smart Refrigerator with AutoFill Water Pitcher - Stainless Steel
# append product :  Frigidaire - 21.4 Cu. Ft. 36" Counter-Depth Side-by-Side Refrigerator - Brushed Steel
# append product :  LG - 28.7 Cu. Ft. 3-Door French Door Refrigerator with Ice Plus - Stainless Steel
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10684\3277654592.py:52: FutureWarning: The behavior of Series.idxmin with all-NA values, or any-NA and skipna=False, is deprecated. In a future version this will raise ValueError
#   min_prix_index = df.loc[group, "prix"].idxmin()
# Erreur : "None of [Index([34], dtype='int32')] are in the [index]"
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10684\3277654592.py:52: FutureWarning: The behavior of Series.idxmin with all-NA values, or any-NA and skipna=False, is deprecated. In a future version this will raise ValueError
#   min_prix_index = df.loc[group, "prix"].idxmin()
# Erreur : "None of [Index([34], dtype='int32')] are in the [index]"
# Data exported to 'temp2Electromenagerscleaned_data'
# Appended site: https://www.bestbuy.com/site/searchpage.jsp?_dyncharset=UTF-8&browsedCategory=pcmcat367400050001&cp=3&id=pcat17071&iht=n&ks=960&list=y&sc=Global&st=categoryid%24pcmcat367400050001&type=page&usc=All%20Categories
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10684\3277654592.py:52: FutureWarning: The behavior of Series.idxmin with all-NA values, or any-NA and skipna=False, is deprecated. In a future version this will raise ValueError
#   min_prix_index = df.loc[group, "prix"].idxmin()
# Removed rows:
#                                                   nom     prix      website  \
# 0                                                 nan      NaN          NaN
# 1   Insignia™ - 18 Cu. Ft. Top-Freezer Refrigerato...   649.99  bestbuy.com
# 32  LG - 27 Cu. Ft. Side-by-Side Smart Refrigerato...  1699.99  bestbuy.com
# 3   Insignia™ - 18.6 Cu. Ft. Bottom Freezer Refrig...   799.99  bestbuy.com
# 4   LG - Counter-Depth MAX 25.5 Cu. Ft. French Doo...  2999.99  bestbuy.com
# 39  Whirlpool - 25.1 Cu. Ft. Side-by-Side Refriger...  1439.99  bestbuy.com
# 42  Frigidaire - 22.3 Cu. Ft. Side-by-Side Refrige...  1299.99  bestbuy.com
# 15  LG - 22.5 Cu. Ft. 4-Door French Door-in-Door C...  3299.99  bestbuy.com
# 48  LG - Counter-Depth MAX 25.5 Cu. Ft. French Doo...  2699.99  bestbuy.com
# 30  LG - 27.7 Cu. Ft. French Door Smart Refrigerat...  1799.99  bestbuy.com
#
#                                                source         date_scraped  \
# 0                                                 NaN                  NaN
# 1   https://www.bestbuy.com/site/refrigerators/all...  2025-01-31 02:35:21
# 32  https://www.bestbuy.com/site/searchpage.jsp?_d...  2025-01-31 02:35:21
# 3   https://www.bestbuy.com/site/refrigerators/all...  2025-01-31 02:35:21
# 4   https://www.bestbuy.com/site/refrigerators/all...  2025-01-31 02:35:21
# 39  https://www.bestbuy.com/site/searchpage.jsp?_d...  2025-01-31 02:35:21
# 42  https://www.bestbuy.com/site/searchpage.jsp?_d...  2025-01-31 02:35:21
# 15  https://www.bestbuy.com/site/refrigerators/all...  2025-01-31 02:35:21
# 48  https://www.bestbuy.com/site/searchpage.jsp?_d...  2025-01-31 02:35:21
# 30  https://www.bestbuy.com/site/searchpage.jsp?_d...  2025-01-31 02:35:21
#
#          category promotion  \
# 0             NaN       NaN
# 1   refrigerators       NaN
# 32  refrigerators       NaN
# 3   refrigerators       NaN
# 4   refrigerators       NaN
# 39  refrigerators       NaN
# 42  refrigerators       NaN
# 15  refrigerators       NaN
# 48  refrigerators       NaN
# 30  refrigerators       NaN
#
#                                                   url  \
# 0                                                 NaN
# 1   https://www.bestbuy.com/site/insignia-18-cu-ft...
# 32  https://www.bestbuy.com/site/lg-27-cu-ft-side-...
# 3   https://www.bestbuy.com/site/insignia-18-6-cu-...
# 4   https://www.bestbuy.com/site/lg-counter-depth-...
# 39  https://www.bestbuy.com/site/whirlpool-25-1-cu...
# 42  https://www.bestbuy.com/site/frigidaire-22-3-c...
# 15  https://www.bestbuy.com/site/lg-22-5-cu-ft-4-d...
# 48  https://www.bestbuy.com/site/lg-counter-depth-...
# 30  https://www.bestbuy.com/site/lg-27-7-cu-ft-fre...
#
#                                           description  \
# 0                                                 NaN
# 1   Specifications Voice Assistant Built-in No Pro...
# 32  Specifications Voice Assistant Built-in No Pro...
# 3   Specifications Voice Assistant Built-in No Pro...
# 4   Specifications Voice Assistant Built-in No Pro...
# 39  Specifications Voice Assistant Built-in No Pro...
# 42  Specifications Voice Assistant Built-in No Pro...
# 15  Specifications Voice Assistant Built-in No Pro...
# 48  Specifications Voice Assistant Built-in No Pro...
# 30  Specifications Voice Assistant Built-in No Pro...
#
#                                                  html  \
# 0                                                 NaN
# 1   <li class="zebra-list-item mt-500 exposed-spec...
# 32  <li class="zebra-list-item mt-500 exposed-spec...
# 3   <li class="zebra-list-item mt-500 exposed-spec...
# 4   <li class="zebra-list-item mt-500 exposed-spec...
# 39  <li class="zebra-list-item mt-500 exposed-spec...
# 42  <li class="zebra-list-item mt-500 exposed-spec...
# 15  <li class="zebra-list-item mt-500 exposed-spec...
# 48  <li class="zebra-list-item mt-500 exposed-spec...
# 30  <li class="zebra-list-item mt-500 exposed-spec...
#
#                                        normalized_nom  \
# 0                                                 nan
# 1   insignia™ - 18 cu. ft. top-freezer refrigerato...
# 32  lg - 27 cu. ft. side-by-side smart refrigerato...
# 3   insignia™ - 18.6 cu. ft. bottom freezer refrig...
# 4   lg - counter-depth max 25.5 cu. ft. french doo...
# 39  whirlpool - 25.1 cu. ft. side-by-side refriger...
# 42  frigidaire - 22.3 cu. ft. side-by-side refrige...
# 15  lg - 22.5 cu. ft. 4-door french door-in-door c...
# 48  lg - counter-depth max 25.5 cu. ft. french doo...
# 30  lg - 27.7 cu. ft. french door smart refrigerat...
#
#                                normalized_description  \
# 0
# 1   specifications voice assistant built-in no pro...
# 32  specifications voice assistant built-in no pro...
# 3   specifications voice assistant built-in no pro...
# 4   specifications voice assistant built-in no pro...
# 39  specifications voice assistant built-in no pro...
# 42  specifications voice assistant built-in no pro...
# 15  specifications voice assistant built-in no pro...
# 48  specifications voice assistant built-in no pro...
# 30  specifications voice assistant built-in no pro...
#
#                                   nom_and_description
# 0                                                nan
# 1   insignia™ - 18 cu. ft. top-freezer refrigerato...
# 32  lg - 27 cu. ft. side-by-side smart refrigerato...
# 3   insignia™ - 18.6 cu. ft. bottom freezer refrig...
# 4   lg - counter-depth max 25.5 cu. ft. french doo...
# 39  whirlpool - 25.1 cu. ft. side-by-side refriger...
# 42  frigidaire - 22.3 cu. ft. side-by-side refrige...
# 15  lg - 22.5 cu. ft. 4-door french door-in-door c...
# 48  lg - counter-depth max 25.5 cu. ft. french doo...
# 30  lg - 27.7 cu. ft. french door smart refrigerat...
# Erreur : '[nan] not in index'
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10684\3277654592.py:52: FutureWarning: The behavior of Series.idxmin with all-NA values, or any-NA and skipna=False, is deprecated. In a future version this will raise ValueError
#   min_prix_index = df.loc[group, "prix"].idxmin()
# Removed rows:
#                                                   nom     prix      website  \
# 0                                                 nan      NaN          NaN
# 1   Insignia™ - 18 Cu. Ft. Top-Freezer Refrigerato...   649.99  bestbuy.com
# 32  LG - 27 Cu. Ft. Side-by-Side Smart Refrigerato...  1699.99  bestbuy.com
# 3   Insignia™ - 18.6 Cu. Ft. Bottom Freezer Refrig...   799.99  bestbuy.com
# 4   LG - Counter-Depth MAX 25.5 Cu. Ft. French Doo...  2999.99  bestbuy.com
# 39  Whirlpool - 25.1 Cu. Ft. Side-by-Side Refriger...  1439.99  bestbuy.com
# 42  Frigidaire - 22.3 Cu. Ft. Side-by-Side Refrige...  1299.99  bestbuy.com
# 15  LG - 22.5 Cu. Ft. 4-Door French Door-in-Door C...  3299.99  bestbuy.com
# 48  LG - Counter-Depth MAX 25.5 Cu. Ft. French Doo...  2699.99  bestbuy.com
# 30  LG - 27.7 Cu. Ft. French Door Smart Refrigerat...  1799.99  bestbuy.com
#
#                                                source         date_scraped  \
# 0                                                 NaN                  NaN
# 1   https://www.bestbuy.com/site/refrigerators/all...  2025-01-31 02:35:21
# 32  https://www.bestbuy.com/site/searchpage.jsp?_d...  2025-01-31 02:35:21
# 3   https://www.bestbuy.com/site/refrigerators/all...  2025-01-31 02:35:21
# 4   https://www.bestbuy.com/site/refrigerators/all...  2025-01-31 02:35:21
# 39  https://www.bestbuy.com/site/searchpage.jsp?_d...  2025-01-31 02:35:21
# 42  https://www.bestbuy.com/site/searchpage.jsp?_d...  2025-01-31 02:35:21
# 15  https://www.bestbuy.com/site/refrigerators/all...  2025-01-31 02:35:21
# 48  https://www.bestbuy.com/site/searchpage.jsp?_d...  2025-01-31 02:35:21
# 30  https://www.bestbuy.com/site/searchpage.jsp?_d...  2025-01-31 02:35:21
#
#          category promotion  \
# 0             NaN       NaN
# 1   refrigerators       NaN
# 32  refrigerators       NaN
# 3   refrigerators       NaN
# 4   refrigerators       NaN
# 39  refrigerators       NaN
# 42  refrigerators       NaN
# 15  refrigerators       NaN
# 48  refrigerators       NaN
# 30  refrigerators       NaN
#
#                                                   url  \
# 0                                                 NaN
# 1   https://www.bestbuy.com/site/insignia-18-cu-ft...
# 32  https://www.bestbuy.com/site/lg-27-cu-ft-side-...
# 3   https://www.bestbuy.com/site/insignia-18-6-cu-...
# 4   https://www.bestbuy.com/site/lg-counter-depth-...
# 39  https://www.bestbuy.com/site/whirlpool-25-1-cu...
# 42  https://www.bestbuy.com/site/frigidaire-22-3-c...
# 15  https://www.bestbuy.com/site/lg-22-5-cu-ft-4-d...
# 48  https://www.bestbuy.com/site/lg-counter-depth-...
# 30  https://www.bestbuy.com/site/lg-27-7-cu-ft-fre...
#
#                                           description  \
# 0                                                 NaN
# 1   Specifications Voice Assistant Built-in No Pro...
# 32  Specifications Voice Assistant Built-in No Pro...
# 3   Specifications Voice Assistant Built-in No Pro...
# 4   Specifications Voice Assistant Built-in No Pro...
# 39  Specifications Voice Assistant Built-in No Pro...
# 42  Specifications Voice Assistant Built-in No Pro...
# 15  Specifications Voice Assistant Built-in No Pro...
# 48  Specifications Voice Assistant Built-in No Pro...
# 30  Specifications Voice Assistant Built-in No Pro...
#
#                                                  html  \
# 0                                                 NaN
# 1   <li class="zebra-list-item mt-500 exposed-spec...
# 32  <li class="zebra-list-item mt-500 exposed-spec...
# 3   <li class="zebra-list-item mt-500 exposed-spec...
# 4   <li class="zebra-list-item mt-500 exposed-spec...
# 39  <li class="zebra-list-item mt-500 exposed-spec...
# 42  <li class="zebra-list-item mt-500 exposed-spec...
# 15  <li class="zebra-list-item mt-500 exposed-spec...
# 48  <li class="zebra-list-item mt-500 exposed-spec...
# 30  <li class="zebra-list-item mt-500 exposed-spec...
#
#                                        normalized_nom  \
# 0                                                 nan
# 1   insignia™ - 18 cu. ft. top-freezer refrigerato...
# 32  lg - 27 cu. ft. side-by-side smart refrigerato...
# 3   insignia™ - 18.6 cu. ft. bottom freezer refrig...
# 4   lg - counter-depth max 25.5 cu. ft. french doo...
# 39  whirlpool - 25.1 cu. ft. side-by-side refriger...
# 42  frigidaire - 22.3 cu. ft. side-by-side refrige...
# 15  lg - 22.5 cu. ft. 4-door french door-in-door c...
# 48  lg - counter-depth max 25.5 cu. ft. french doo...
# 30  lg - 27.7 cu. ft. french door smart refrigerat...
#
#                                normalized_description  \
# 0
# 1   specifications voice assistant built-in no pro...
# 32  specifications voice assistant built-in no pro...
# 3   specifications voice assistant built-in no pro...
# 4   specifications voice assistant built-in no pro...
# 39  specifications voice assistant built-in no pro...
# 42  specifications voice assistant built-in no pro...
# 15  specifications voice assistant built-in no pro...
# 48  specifications voice assistant built-in no pro...
# 30  specifications voice assistant built-in no pro...
#
#                                   nom_and_description
# 0                                                nan
# 1   insignia™ - 18 cu. ft. top-freezer refrigerato...
# 32  lg - 27 cu. ft. side-by-side smart refrigerato...
# 3   insignia™ - 18.6 cu. ft. bottom freezer refrig...
# 4   lg - counter-depth max 25.5 cu. ft. french doo...
# 39  whirlpool - 25.1 cu. ft. side-by-side refriger...
# 42  frigidaire - 22.3 cu. ft. side-by-side refrige...
# 15  lg - 22.5 cu. ft. 4-door french door-in-door c...
# 48  lg - counter-depth max 25.5 cu. ft. french doo...
# 30  lg - 27.7 cu. ft. french door smart refrigerat...
# Erreur : '[nan] not in index'
# Data exported to 'temp2Electromenagerscleaned_data'
# Appended site: https://www.bestbuy.com/site/searchpage.jsp?_dyncharset=UTF-8&browsedCategory=pcmcat367400050001&cp=3&id=pcat17071&iht=n&ks=960&list=y&sc=Global&st=categoryid%24pcmcat367400050001&type=page&usc=All%20Categories
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10684\3277654592.py:52: FutureWarning: The behavior of Series.idxmin with all-NA values, or any-NA and skipna=False, is deprecated. In a future version this will raise ValueError
#   min_prix_index = df.loc[group, "prix"].idxmin()
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10684\3277654592.py:52: FutureWarning: The behavior of Series.idxmin with all-NA values, or any-NA and skipna=False, is deprecated. In a future version this will raise ValueError
#   min_prix_index = df.loc[group, "prix"].idxmin()
# Removed rows:
#                                                   nom     prix      website  \
# 0                                                 nan      NaN          NaN
# 1   Insignia™ - 18 Cu. Ft. Top-Freezer Refrigerato...   649.99  bestbuy.com
# 32  LG - 27 Cu. Ft. Side-by-Side Smart Refrigerato...  1699.99  bestbuy.com
# 3   Insignia™ - 18.6 Cu. Ft. Bottom Freezer Refrig...   799.99  bestbuy.com
# 4   LG - Counter-Depth MAX 25.5 Cu. Ft. French Doo...  2999.99  bestbuy.com
# 39  Whirlpool - 25.1 Cu. Ft. Side-by-Side Refriger...  1439.99  bestbuy.com
# 42  Frigidaire - 22.3 Cu. Ft. Side-by-Side Refrige...  1299.99  bestbuy.com
# 15  LG - 22.5 Cu. Ft. 4-Door French Door-in-Door C...  3299.99  bestbuy.com
# 48  LG - Counter-Depth MAX 25.5 Cu. Ft. French Doo...  2699.99  bestbuy.com
# 30  LG - 27.7 Cu. Ft. French Door Smart Refrigerat...  1799.99  bestbuy.com
#
#                                                source         date_scraped  \
# 0                                                 NaN                  NaN
# 1   https://www.bestbuy.com/site/refrigerators/all...  2025-01-31 02:35:21
# 32  https://www.bestbuy.com/site/searchpage.jsp?_d...  2025-01-31 02:35:21
# 3   https://www.bestbuy.com/site/refrigerators/all...  2025-01-31 02:35:21
# 4   https://www.bestbuy.com/site/refrigerators/all...  2025-01-31 02:35:21
# 39  https://www.bestbuy.com/site/searchpage.jsp?_d...  2025-01-31 02:35:21
# 42  https://www.bestbuy.com/site/searchpage.jsp?_d...  2025-01-31 02:35:21
# 15  https://www.bestbuy.com/site/refrigerators/all...  2025-01-31 02:35:21
# 48  https://www.bestbuy.com/site/searchpage.jsp?_d...  2025-01-31 02:35:21
# 30  https://www.bestbuy.com/site/searchpage.jsp?_d...  2025-01-31 02:35:21
#
#          category promotion  \
# 0             NaN       NaN
# 1   refrigerators       NaN
# 32  refrigerators       NaN
# 3   refrigerators       NaN
# 4   refrigerators       NaN
# 39  refrigerators       NaN
# 42  refrigerators       NaN
# 15  refrigerators       NaN
# 48  refrigerators       NaN
# 30  refrigerators       NaN
#
#                                                   url  \
# 0                                                 NaN
# 1   https://www.bestbuy.com/site/insignia-18-cu-ft...
# 32  https://www.bestbuy.com/site/lg-27-cu-ft-side-...
# 3   https://www.bestbuy.com/site/insignia-18-6-cu-...
# 4   https://www.bestbuy.com/site/lg-counter-depth-...
# 39  https://www.bestbuy.com/site/whirlpool-25-1-cu...
# 42  https://www.bestbuy.com/site/frigidaire-22-3-c...
# 15  https://www.bestbuy.com/site/lg-22-5-cu-ft-4-d...
# 48  https://www.bestbuy.com/site/lg-counter-depth-...
# 30  https://www.bestbuy.com/site/lg-27-7-cu-ft-fre...
#
#                                           description  \
# 0                                                 NaN
# 1   Specifications Voice Assistant Built-in No Pro...
# 32  Specifications Voice Assistant Built-in No Pro...
# 3   Specifications Voice Assistant Built-in No Pro...
# 4   Specifications Voice Assistant Built-in No Pro...
# 39  Specifications Voice Assistant Built-in No Pro...
# 42  Specifications Voice Assistant Built-in No Pro...
# 15  Specifications Voice Assistant Built-in No Pro...
# 48  Specifications Voice Assistant Built-in No Pro...
# 30  Specifications Voice Assistant Built-in No Pro...
#
#                                                  html  \
# 0                                                 NaN
# 1   <li class="zebra-list-item mt-500 exposed-spec...
# 32  <li class="zebra-list-item mt-500 exposed-spec...
# 3   <li class="zebra-list-item mt-500 exposed-spec...
# 4   <li class="zebra-list-item mt-500 exposed-spec...
# 39  <li class="zebra-list-item mt-500 exposed-spec...
# 42  <li class="zebra-list-item mt-500 exposed-spec...
# 15  <li class="zebra-list-item mt-500 exposed-spec...
# 48  <li class="zebra-list-item mt-500 exposed-spec...
# 30  <li class="zebra-list-item mt-500 exposed-spec...
#
#                                        normalized_nom  \
# 0                                                 nan
# 1   insignia™ - 18 cu. ft. top-freezer refrigerato...
# 32  lg - 27 cu. ft. side-by-side smart refrigerato...
# 3   insignia™ - 18.6 cu. ft. bottom freezer refrig...
# 4   lg - counter-depth max 25.5 cu. ft. french doo...
# 39  whirlpool - 25.1 cu. ft. side-by-side refriger...
# 42  frigidaire - 22.3 cu. ft. side-by-side refrige...
# 15  lg - 22.5 cu. ft. 4-door french door-in-door c...
# 48  lg - counter-depth max 25.5 cu. ft. french doo...
# 30  lg - 27.7 cu. ft. french door smart refrigerat...
#
#                                normalized_description  \
# 0
# 1   specifications voice assistant built-in no pro...
# 32  specifications voice assistant built-in no pro...
# 3   specifications voice assistant built-in no pro...
# 4   specifications voice assistant built-in no pro...
# 39  specifications voice assistant built-in no pro...
# 42  specifications voice assistant built-in no pro...
# 15  specifications voice assistant built-in no pro...
# 48  specifications voice assistant built-in no pro...
# 30  specifications voice assistant built-in no pro...
#
#                                   nom_and_description
# 0                                                nan
# 1   insignia™ - 18 cu. ft. top-freezer refrigerato...
# 32  lg - 27 cu. ft. side-by-side smart refrigerato...
# 3   insignia™ - 18.6 cu. ft. bottom freezer refrig...
# 4   lg - counter-depth max 25.5 cu. ft. french doo...
# 39  whirlpool - 25.1 cu. ft. side-by-side refriger...
# 42  frigidaire - 22.3 cu. ft. side-by-side refrige...
# 15  lg - 22.5 cu. ft. 4-door french door-in-door c...
# 48  lg - counter-depth max 25.5 cu. ft. french doo...
# 30  lg - 27.7 cu. ft. french door smart refrigerat...
# Erreur : '[nan] not in index'
# Removed rows:
#                                                   nom     prix      website  \
# 0                                                 nan      NaN          NaN
# 1   Insignia™ - 18 Cu. Ft. Top-Freezer Refrigerato...   649.99  bestbuy.com
# 32  LG - 27 Cu. Ft. Side-by-Side Smart Refrigerato...  1699.99  bestbuy.com
# 3   Insignia™ - 18.6 Cu. Ft. Bottom Freezer Refrig...   799.99  bestbuy.com
# 4   LG - Counter-Depth MAX 25.5 Cu. Ft. French Doo...  2999.99  bestbuy.com
# 39  Whirlpool - 25.1 Cu. Ft. Side-by-Side Refriger...  1439.99  bestbuy.com
# 42  Frigidaire - 22.3 Cu. Ft. Side-by-Side Refrige...  1299.99  bestbuy.com
# 15  LG - 22.5 Cu. Ft. 4-Door French Door-in-Door C...  3299.99  bestbuy.com
# 48  LG - Counter-Depth MAX 25.5 Cu. Ft. French Doo...  2699.99  bestbuy.com
# 30  LG - 27.7 Cu. Ft. French Door Smart Refrigerat...  1799.99  bestbuy.com
#
#                                                source         date_scraped  \
# 0                                                 NaN                  NaN
# 1   https://www.bestbuy.com/site/refrigerators/all...  2025-01-31 02:35:21
# 32  https://www.bestbuy.com/site/searchpage.jsp?_d...  2025-01-31 02:35:21
# 3   https://www.bestbuy.com/site/refrigerators/all...  2025-01-31 02:35:21
# 4   https://www.bestbuy.com/site/refrigerators/all...  2025-01-31 02:35:21
# 39  https://www.bestbuy.com/site/searchpage.jsp?_d...  2025-01-31 02:35:21
# 42  https://www.bestbuy.com/site/searchpage.jsp?_d...  2025-01-31 02:35:21
# 15  https://www.bestbuy.com/site/refrigerators/all...  2025-01-31 02:35:21
# 48  https://www.bestbuy.com/site/searchpage.jsp?_d...  2025-01-31 02:35:21
# 30  https://www.bestbuy.com/site/searchpage.jsp?_d...  2025-01-31 02:35:21
#
#          category promotion  \
# 0             NaN       NaN
# 1   refrigerators       NaN
# 32  refrigerators       NaN
# 3   refrigerators       NaN
# 4   refrigerators       NaN
# 39  refrigerators       NaN
# 42  refrigerators       NaN
# 15  refrigerators       NaN
# 48  refrigerators       NaN
# 30  refrigerators       NaN
#
#                                                   url  \
# 0                                                 NaN
# 1   https://www.bestbuy.com/site/insignia-18-cu-ft...
# 32  https://www.bestbuy.com/site/lg-27-cu-ft-side-...
# 3   https://www.bestbuy.com/site/insignia-18-6-cu-...
# 4   https://www.bestbuy.com/site/lg-counter-depth-...
# 39  https://www.bestbuy.com/site/whirlpool-25-1-cu...
# 42  https://www.bestbuy.com/site/frigidaire-22-3-c...
# 15  https://www.bestbuy.com/site/lg-22-5-cu-ft-4-d...
# 48  https://www.bestbuy.com/site/lg-counter-depth-...
# 30  https://www.bestbuy.com/site/lg-27-7-cu-ft-fre...
#
#                                           description  \
# 0                                                 NaN
# 1   Specifications Voice Assistant Built-in No Pro...
# 32  Specifications Voice Assistant Built-in No Pro...
# 3   Specifications Voice Assistant Built-in No Pro...
# 4   Specifications Voice Assistant Built-in No Pro...
# 39  Specifications Voice Assistant Built-in No Pro...
# 42  Specifications Voice Assistant Built-in No Pro...
# 15  Specifications Voice Assistant Built-in No Pro...
# 48  Specifications Voice Assistant Built-in No Pro...
# 30  Specifications Voice Assistant Built-in No Pro...
#
#                                                  html  \
# 0                                                 NaN
# 1   <li class="zebra-list-item mt-500 exposed-spec...
# 32  <li class="zebra-list-item mt-500 exposed-spec...
# 3   <li class="zebra-list-item mt-500 exposed-spec...
# 4   <li class="zebra-list-item mt-500 exposed-spec...
# 39  <li class="zebra-list-item mt-500 exposed-spec...
# 42  <li class="zebra-list-item mt-500 exposed-spec...
# 15  <li class="zebra-list-item mt-500 exposed-spec...
# 48  <li class="zebra-list-item mt-500 exposed-spec...
# 30  <li class="zebra-list-item mt-500 exposed-spec...
#
#                                        normalized_nom  \
# 0                                                 nan
# 1   insignia™ - 18 cu. ft. top-freezer refrigerato...
# 32  lg - 27 cu. ft. side-by-side smart refrigerato...
# 3   insignia™ - 18.6 cu. ft. bottom freezer refrig...
# 4   lg - counter-depth max 25.5 cu. ft. french doo...
# 39  whirlpool - 25.1 cu. ft. side-by-side refriger...
# 42  frigidaire - 22.3 cu. ft. side-by-side refrige...
# 15  lg - 22.5 cu. ft. 4-door french door-in-door c...
# 48  lg - counter-depth max 25.5 cu. ft. french doo...
# 30  lg - 27.7 cu. ft. french door smart refrigerat...
#
#                                normalized_description  \
# 0
# 1   specifications voice assistant built-in no pro...
# 32  specifications voice assistant built-in no pro...
# 3   specifications voice assistant built-in no pro...
# 4   specifications voice assistant built-in no pro...
# 39  specifications voice assistant built-in no pro...
# 42  specifications voice assistant built-in no pro...
# 15  specifications voice assistant built-in no pro...
# 48  specifications voice assistant built-in no pro...
# 30  specifications voice assistant built-in no pro...
#
#                                   nom_and_description
# 0                                                nan
# 1   insignia™ - 18 cu. ft. top-freezer refrigerato...
# 32  lg - 27 cu. ft. side-by-side smart refrigerato...
# 3   insignia™ - 18.6 cu. ft. bottom freezer refrig...
# 4   lg - counter-depth max 25.5 cu. ft. french doo...
# 39  whirlpool - 25.1 cu. ft. side-by-side refriger...
# 42  frigidaire - 22.3 cu. ft. side-by-side refrige...
# 15  lg - 22.5 cu. ft. 4-door french door-in-door c...
# 48  lg - counter-depth max 25.5 cu. ft. french doo...
# 30  lg - 27.7 cu. ft. french door smart refrigerat...
# Erreur : '[nan] not in index'
# Data exported to 'temp2Electromenagerscleaned_data'
# Appended site: https://www.bestbuy.com/site/searchpage.jsp?_dyncharset=UTF-8&browsedCategory=pcmcat367400050001&cp=3&id=pcat17071&iht=n&ks=960&list=y&sc=Global&st=categoryid%24pcmcat367400050001&type=page&usc=All%20Categories
# Add :  https://www.bestbuy.com/site/searchpage.jsp?_dyncharset=UTF-8&browsedCategory=pcmcat367400050001&cp=3&id=pcat17071&iht=n&ks=960&list=y&sc=Global&st=categoryid%24pcmcat367400050001&type=page&usc=All%20Categories
# Opened :  https://www.bestbuy.com/site/home-appliances/freezers-ice-makers/abcat0902000.c?id=abcat0902000&intl=nosplash
# append product :  Frigidaire - 13.0 Cu. Ft. Frost-Free Upright Freezer with Interior Light - White
# append product :  Insignia™ - 7.0 Cu. Ft. Garage Ready-Chest Freezer - White
# append product :  Insignia™ - 10.2 Cu. Ft. Garage-Ready Chest Freezer - White
# append product :  Insignia™ - 21 Cu. Ft. Garage Ready Convertible Upright Freezer with ENERGY STAR Certification - White
# append product :  Whirlpool - 16 Cu. Ft. Chest Freezer with Basket - White
# append product :  Insignia™ - 17 Cu. Ft. Garage Ready Convertible Upright Freezer with ENERGY STAR Certification - Stainless Steel
# append product :  Insignia™ - 7 Cu. Ft. Garage Ready Upright Convertible Freezer with ENERGY STAR Certification - Stainless Steel Look
# append product :  Whirlpool - 15" 29-Lb. Freestanding Icemaker - Stainless Steel
# append product :  Insignia™ - 14.0 Cu. Ft. Garage-Ready Chest Freezer - White
# append product :  Insignia™ - 17 Cu. Ft. Garage Ready Convertible Upright Freezer with ENERGY STAR Certification - White
# append product :  Frigidaire - 13.0 Cu. Ft. Frost-Free Upright Freezer with Interior Light - White
# append product :  Insignia™ - 7 Cu. Ft. Garage Ready Upright Convertible Freezer with ENERGY STAR Certification - White
# append product :  Insignia™ - Portable Ice Maker with Auto Shut-Off - White
# append product :  Insignia™ - 5.0 Cu. Ft. Garage Ready-Chest Freezer - White
# append product :  Insignia™ - 13.8 Cu. Ft. Garage Ready Convertible Upright Freezer with ENERGY STAR Certification - Stainless Steel
# append product :  Insignia™ - 3.5 Cu. Ft. Garage-Ready Chest Freezer - White
# append product :  Frigidaire - 20.0 Cu. Ft. Upright Freezer - Carbon
# append product :  GE Profile - Opal 2.0 Ultra Nugget Ice Maker with Side Tank and Scale Inhibiting Filter - Stainless Steel
# append product :  Frigidaire - 20.0 Cu. Ft. Upright Freezer - White
# next_page :  2
# https://www.bestbuy.com/site/searchpage.jsp?_dyncharset=UTF-8&browsedCategory=abcat0902000&cp=2&id=pcat17071&iht=n&ks=960&list=y&sc=Global&st=categoryid%24abcat0902000&type=page&usc=All%20Categories
# Opened :  https://www.bestbuy.com/site/searchpage.jsp?_dyncharset=UTF-8&browsedCategory=abcat0902000&cp=2&id=pcat17071&iht=n&ks=960&list=y&sc=Global&st=categoryid%24abcat0902000&type=page&usc=All%20Categories
# append product :  Monogram - Forge Heated Ice Press - Black
# append product :  Costway - 2-in-1 Countertop Ice Maker Water Dispenser 48Lbs/24H w/ Scoop - Black/Silver
# append product :  GE Profile - Opal 2.0 38-lb. Portable Ice maker with Nugget Ice Production, XL 1 Gallon Side Tank and Built-in WiFi - Black Stainless Steel
# append product :  Insignia™ - 13.8 Cu. Ft. Garage Ready Convertible Upright Freezer with ENERGY STAR Certification - White
# append product :  Whirlpool - 9 Cu. Ft. Convertible Freezer to Refrigerator with Baskets - White
# append product :  GE - 21.3 Cu. Ft. Frost-Free Upright Freezer - White
# append product :  Frigidaire - 15.5 Cu. Ft. Frost-Free Upright Freezer with Interior Light - Brushed Steel
# append product :  Ecozy - 33lb. Smart Nugget Countertop Ice Maker, Portable Pebble Ice Machine with Voice Control
# append product :  Insignia™ - 7 Cu. Ft. Garage Ready Upright Freezer - White
# append product :  GE Profile - Opal 1.0 Nugget Ice Maker With Side Tank - Black
# append product :  Samsung - 11.4 cu. ft. Capacity Convertible Upright Freezer - Stainless Steel Look
# append product :  Frigidaire - 20.0 Cu. Ft. Upright Freezer - White
# append product :  GE Profile - Opal 2.0 Ultra Nugget Ice Maker with Scale Inhibiting Filter - Carbon Black
# append product :  Frigidaire - 6 Cu. Ft. Upright Freezer - White
# append product :  GE - 21.7 Cu. Ft. Chest Freezer - White
# append product :  Frigidaire - 15.5 Cu. Ft. Frost-Free Upright Freezer with Interior Light - White
# append product :  Frigidaire - 19.8 Cu. Ft. Chest Freezer - White
# append product :  KitchenAid - 15" 22.8-Lb. Freestanding Icemaker - Stainless Steel
# append product :  Whirlpool - 19.6 Cu. Ft. Frost-Free Upright Freezer - White
# next_page :  3
# https://www.bestbuy.com/site/searchpage.jsp?_dyncharset=UTF-8&browsedCategory=abcat0902000&cp=3&id=pcat17071&iht=n&ks=960&list=y&sc=Global&st=categoryid%24abcat0902000&type=page&usc=All%20Categories
# Opened :  https://www.bestbuy.com/site/searchpage.jsp?_dyncharset=UTF-8&browsedCategory=abcat0902000&cp=3&id=pcat17071&iht=n&ks=960&list=y&sc=Global&st=categoryid%24abcat0902000&type=page&usc=All%20Categories
# append product :  Monogram - Forge Heated Ice Press - Black
# append product :  Costway - Built-in Ice Maker Free-Standing/Under Counter Machine 80lbs/Day w/ Drain Pump - Silver/Black
# append product :  Frigidaire - 24.8 Cu. Ft. Chest Freezer - White
# append product :  KitchenAid - 15" 22.8-Lb. Built-In Icemaker - Stainless Steel
# append product :  KitchenAid - 18" 29-Lb. Built-In Ice Maker - Stainless Steel
# append product :  GE - 21.3 Cu. Ft. Frost-Free Upright Freezer - White
# append product :  KitchenAid - 15" 22.8-Lb. Built-In Icemaker - Black Stainless Steel
# append product :  GE - 14.1 Cu. Ft. Frost-Free Upright Freezer - White
# append product :  Ecozy - 33 lb. Countertop Nugget Ice Maker with Self-Cleaning Ice Machine, Chewable Pellet Ice Daily
# append product :  Frigidaire - 13 Cu. Ft Upright Freezer - Brushed Steel
# append product :  Frigidaire - 20 Cu. Ft. Upright Freezer - White
# append product :  Frigidaire - Professional 19 Cu. Ft. Single-Door Freezer - Stainless Steel
# append product :  Frigidaire - 14.8 Cu. Ft. Chest Freezer - White
# append product :  SPT - 3.0 Cu. Ft. Upright Freezer - Stainless Steel
# append product :  GE - 17.3 Cu. Ft. Frost-Free Upright Freezer - White
# append product :  GE Profile - 15" 26-Lb. Freestanding Icemaker with Gourmet Clear Ice - Custom Panel Ready
# append product :  GE - 15.7 Cu. Ft. Chest Freezer - White
# append product :  Whirlpool - 15.7 Cu. Ft. Frost-Free Upright Freezer - White
# append product :  Ecozy - Smart Nugget Ice Maker Countertop, First Full-Color Smart Panel Ice Machine with APP Control, 44 lbs/24H
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10684\3277654592.py:52: FutureWarning: The behavior of Series.idxmin with all-NA values, or any-NA and skipna=False, is deprecated. In a future version this will raise ValueError
#   min_prix_index = df.loc[group, "prix"].idxmin()
# Erreur : '[65] not in index'
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10684\3277654592.py:52: FutureWarning: The behavior of Series.idxmin with all-NA values, or any-NA and skipna=False, is deprecated. In a future version this will raise ValueError
#   min_prix_index = df.loc[group, "prix"].idxmin()
# Erreur : '[65] not in index'
# Data exported to 'temp2Electromenagerscleaned_data'
# Appended site: https://www.bestbuy.com/site/searchpage.jsp?_dyncharset=UTF-8&browsedCategory=abcat0902000&cp=3&id=pcat17071&iht=n&ks=960&list=y&sc=Global&st=categoryid%24abcat0902000&type=page&usc=All%20Categories
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10684\3277654592.py:52: FutureWarning: The behavior of Series.idxmin with all-NA values, or any-NA and skipna=False, is deprecated. In a future version this will raise ValueError
#   min_prix_index = df.loc[group, "prix"].idxmin()
# Removed rows:
#                                                   nom     prix      website  \
# 0                                                 nan      NaN          NaN
# 1   Insignia™ - 18 Cu. Ft. Top-Freezer Refrigerato...   649.99  bestbuy.com
# 32  LG - 27 Cu. Ft. Side-by-Side Smart Refrigerato...  1699.99  bestbuy.com
# 3   Insignia™ - 18.6 Cu. Ft. Bottom Freezer Refrig...   799.99  bestbuy.com
# 4   LG - Counter-Depth MAX 25.5 Cu. Ft. French Doo...  2999.99  bestbuy.com
# 39  Whirlpool - 25.1 Cu. Ft. Side-by-Side Refriger...  1439.99  bestbuy.com
# 42  Frigidaire - 22.3 Cu. Ft. Side-by-Side Refrige...  1299.99  bestbuy.com
# 15  LG - 22.5 Cu. Ft. 4-Door French Door-in-Door C...  3299.99  bestbuy.com
# 48  LG - Counter-Depth MAX 25.5 Cu. Ft. French Doo...  2699.99  bestbuy.com
# 92  KitchenAid - 15" 22.8-Lb. Built-In Icemaker Steel  2834.99  bestbuy.com
# 84  Frigidaire - 15.5 Cu. Ft. Frost-Free Upright F...   649.99  bestbuy.com
# 86    KitchenAid - 15" 22.8-Lb. Freestanding Icemaker  2744.99  bestbuy.com
# 56  Insignia™ - 7.0 Cu. Ft. Garage Ready-Chest Fre...   249.99  bestbuy.com
# 58  Insignia™ - 21 Cu. Ft. Garage Ready Convertibl...   899.99  bestbuy.com
# 60  Insignia™ - 7 Cu. Ft. Garage Ready Upright Con...   329.99  bestbuy.com
# 30  LG - 27.7 Cu. Ft. French Door Smart Refrigerat...  1799.99  bestbuy.com
#
#                                                source         date_scraped  \
# 0                                                 NaN                  NaN
# 1   https://www.bestbuy.com/site/refrigerators/all...  2025-01-31 02:35:21
# 32  https://www.bestbuy.com/site/searchpage.jsp?_d...  2025-01-31 02:35:21
# 3   https://www.bestbuy.com/site/refrigerators/all...  2025-01-31 02:35:21
# 4   https://www.bestbuy.com/site/refrigerators/all...  2025-01-31 02:35:21
# 39  https://www.bestbuy.com/site/searchpage.jsp?_d...  2025-01-31 02:35:21
# 42  https://www.bestbuy.com/site/searchpage.jsp?_d...  2025-01-31 02:35:21
# 15  https://www.bestbuy.com/site/refrigerators/all...  2025-01-31 02:35:21
# 48  https://www.bestbuy.com/site/searchpage.jsp?_d...  2025-01-31 02:35:21
# 92  https://www.bestbuy.com/site/searchpage.jsp?_d...  2025-01-31 02:35:21
# 84  https://www.bestbuy.com/site/searchpage.jsp?_d...  2025-01-31 02:35:21
# 86  https://www.bestbuy.com/site/searchpage.jsp?_d...  2025-01-31 02:35:21
# 56  https://www.bestbuy.com/site/home-appliances/f...  2025-01-31 02:35:21
# 58  https://www.bestbuy.com/site/home-appliances/f...  2025-01-31 02:35:21
# 60  https://www.bestbuy.com/site/home-appliances/f...  2025-01-31 02:35:21
# 30  https://www.bestbuy.com/site/searchpage.jsp?_d...  2025-01-31 02:35:21
#
#          category promotion  \
# 0             NaN       NaN
# 1   refrigerators       NaN
# 32  refrigerators       NaN
# 3   refrigerators       NaN
# 4   refrigerators       NaN
# 39  refrigerators       NaN
# 42  refrigerators       NaN
# 15  refrigerators       NaN
# 48  refrigerators       NaN
# 92       freezers       NaN
# 84       freezers       NaN
# 86       freezers       NaN
# 56       freezers       NaN
# 58       freezers       NaN
# 60       freezers       NaN
# 30  refrigerators       NaN
#
#                                                   url  \
# 0                                                 NaN
# 1   https://www.bestbuy.com/site/insignia-18-cu-ft...
# 32  https://www.bestbuy.com/site/lg-27-cu-ft-side-...
# 3   https://www.bestbuy.com/site/insignia-18-6-cu-...
# 4   https://www.bestbuy.com/site/lg-counter-depth-...
# 39  https://www.bestbuy.com/site/whirlpool-25-1-cu...
# 42  https://www.bestbuy.com/site/frigidaire-22-3-c...
# 15  https://www.bestbuy.com/site/lg-22-5-cu-ft-4-d...
# 48  https://www.bestbuy.com/site/lg-counter-depth-...
# 92  https://www.bestbuy.com/site/kitchenaid-15-22-...
# 84  https://www.bestbuy.com/site/frigidaire-15-5-c...
# 86  https://www.bestbuy.com/site/kitchenaid-15-22-...
# 56  https://www.bestbuy.com/site/insignia-7-0-cu-f...
# 58  https://www.bestbuy.com/site/insignia-21-cu-ft...
# 60  https://www.bestbuy.com/site/insignia-7-cu-ft-...
# 30  https://www.bestbuy.com/site/lg-27-7-cu-ft-fre...
#
#                                           description  \
# 0                                                 NaN
# 1   Specifications Voice Assistant Built-in No Pro...
# 32  Specifications Voice Assistant Built-in No Pro...
# 3   Specifications Voice Assistant Built-in No Pro...
# 4   Specifications Voice Assistant Built-in No Pro...
# 39  Specifications Voice Assistant Built-in No Pro...
# 42  Specifications Voice Assistant Built-in No Pro...
# 15  Specifications Voice Assistant Built-in No Pro...
# 48  Specifications Voice Assistant Built-in No Pro...
# 92  Specifications Product Height 34 1/10 inches P...
# 84  Specifications Product Height 67 3/4 inches Pr...
# 86  Specifications Product Height 34 inches Produc...
# 56  Specifications Product Height 33 1/2 inches Pr...
# 58  Specifications Product Height 76 13/16 inches ...
# 60  Specifications Product Height 56 1/8 inches Pr...
# 30  Specifications Voice Assistant Built-in No Pro...
#
#                                                  html  \
# 0                                                 NaN
# 1   <li class="zebra-list-item mt-500 exposed-spec...
# 32  <li class="zebra-list-item mt-500 exposed-spec...
# 3   <li class="zebra-list-item mt-500 exposed-spec...
# 4   <li class="zebra-list-item mt-500 exposed-spec...
# 39  <li class="zebra-list-item mt-500 exposed-spec...
# 42  <li class="zebra-list-item mt-500 exposed-spec...
# 15  <li class="zebra-list-item mt-500 exposed-spec...
# 48  <li class="zebra-list-item mt-500 exposed-spec...
# 92  <li class="zebra-list-item mt-500 exposed-spec...
# 84  <li class="zebra-list-item mt-500 exposed-spec...
# 86  <li class="zebra-list-item mt-500 exposed-spec...
# 56  <li class="zebra-list-item mt-500 exposed-spec...
# 58  <li class="zebra-list-item mt-500 exposed-spec...
# 60  <li class="zebra-list-item mt-500 exposed-spec...
# 30  <li class="zebra-list-item mt-500 exposed-spec...
#
#                                        normalized_nom  \
# 0                                                 nan
# 1   insignia™ - 18 cu. ft. top-freezer refrigerato...
# 32  lg - 27 cu. ft. side-by-side smart refrigerato...
# 3   insignia™ - 18.6 cu. ft. bottom freezer refrig...
# 4   lg - counter-depth max 25.5 cu. ft. french doo...
# 39  whirlpool - 25.1 cu. ft. side-by-side refriger...
# 42  frigidaire - 22.3 cu. ft. side-by-side refrige...
# 15  lg - 22.5 cu. ft. 4-door french door-in-door c...
# 48  lg - counter-depth max 25.5 cu. ft. french doo...
# 92  kitchenaid - 15" 22.8-lb. built-in icemaker steel
# 84  frigidaire - 15.5 cu. ft. frost-free upright f...
# 86    kitchenaid - 15" 22.8-lb. freestanding icemaker
# 56  insignia™ - 7.0 cu. ft. garage ready-chest fre...
# 58  insignia™ - 21 cu. ft. garage ready convertibl...
# 60  insignia™ - 7 cu. ft. garage ready upright con...
# 30  lg - 27.7 cu. ft. french door smart refrigerat...
#
#                                normalized_description  \
# 0
# 1   specifications voice assistant built-in no pro...
# 32  specifications voice assistant built-in no pro...
# 3   specifications voice assistant built-in no pro...
# ...
# 3    insignia™ - 18.6 cu. ft. bottom freezer refrig...
# 4    lg - counter-depth max 25.5 cu. ft. french doo...
# 15   lg - 22.5 cu. ft. 4-door french door-in-door c...
# ..                                                 ...
# 394  allstate 3 years (for major appliances above $...
# 454  ge 17.3 cu. ft. frost free garage ready uprigh...
# 482  lg 1.8 cu. ft. smart wi-fi enabled over-the-ra...
# 494  samsung 4-piece gas kitchen package with count...
# 499  allstate 3 years (for kitchen suites above $40...
#
# [106 rows x 13 columns]
# Erreur : '[nan] not in index'
# Data exported to 'temp2Electromenagerscleaned_data'
# Appended site: https://www.whirlpool.com/kitchen/cooking/microwaves/see-all.html?plp=%3ABest%20Seller%3Acategory%3AKitchenCookingMicrowaves%3AinStock%3Atrue&plpView=list&currentPage=0
# Add :  https://www.whirlpool.com/kitchen/cooking/microwaves/see-all.html?plp=%3ABest%20Seller%3Acategory%3AKitchenCookingMicrowaves%3AinStock%3Atrue&plpView=list&currentPage=0
# Error loading https://www.whirlpool.com/kitchen/cooking/wall-ovens/see-all.html?plp=%3ABest%20Seller%3Acategory%3AKitchenCookingWallOvens%3AinStock%3Atrue&plpView=list&currentPage=0: HTTPConnectionPool(host='localhost', port=50512): Read timed out. (read timeout=120)
# Opened :  https://www.whirlpool.com/kitchen/cooking/cooktops/see-all.html?plp=%3ABest%20Seller%3Acategory%3AKitchenCookingCooktops%3AshowMajorProductsOnly%3Atrue%3AinStock%3Atrue&plpView=grid&currentPage=0
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10684\3277654592.py:52: FutureWarning: The behavior of Series.idxmin with all-NA values, or any-NA and skipna=False, is deprecated. In a future version this will raise ValueError
#   min_prix_index = df.loc[group, "prix"].idxmin()
# Removed rows:
#                                                    nom     prix      website  \
# 0                                                  nan      NaN          NaN
# 1    Insignia™ - 18 Cu. Ft. Top-Freezer Refrigerato...   649.99  bestbuy.com
# 3    Insignia™ - 18.6 Cu. Ft. Bottom Freezer Refrig...   799.99  bestbuy.com
# 4    LG - Counter-Depth MAX 25.5 Cu. Ft. French Doo...  2999.99  bestbuy.com
# 15   LG - 22.5 Cu. Ft. 4-Door French Door-in-Door C...  3299.99  bestbuy.com
# ..                                                 ...      ...          ...
# 394  Allstate 3 Years (For Major Appliances Above $...   159.99   costco.com
# 454  GE 17.3 cu. ft. Frost Free Garage Ready Uprigh...   829.99   costco.com
# 482  LG 1.8 cu. ft. Smart Wi-Fi Enabled Over-the-Ra...   449.99   costco.com
# 494  Samsung 4-piece GAS Kitchen Package with Count...  4479.96   costco.com
# 499  Allstate 3 Years (For Kitchen Suites Above $4000)   399.99   costco.com
#
#                                                 source         date_scraped  \
# 0                                                  NaN                  NaN
# 1    https://www.bestbuy.com/site/refrigerators/all...  2025-01-31 02:35:21
# 3    https://www.bestbuy.com/site/refrigerators/all...  2025-01-31 02:35:21
# 4    https://www.bestbuy.com/site/refrigerators/all...  2025-01-31 02:35:21
# 15   https://www.bestbuy.com/site/refrigerators/all...  2025-01-31 02:35:21
# ..                                                 ...                  ...
# 394          https://www.costco.com/refrigerators.html  2025-01-31 02:35:21
# 454    https://www.costco.com/freezers-ice-makers.html  2025-01-31 02:35:21
# 482             https://www.costco.com/microwaves.html  2025-01-31 02:35:21
# 494         https://www.costco.com/kitchen-suites.html  2025-01-31 02:35:21
# 499         https://www.costco.com/kitchen-suites.html  2025-01-31 02:35:21
#
#            category promotion  \
# 0               NaN       NaN
# 1     refrigerators       NaN
# 3     refrigerators       NaN
# 4     refrigerators       NaN
# 15    refrigerators       NaN
# ..              ...       ...
# 394   refrigerators       NaN
# 454        freezers       NaN
# 482      microwaves       NaN
# 494  kitchen-suites       NaN
# 499  kitchen-suites       NaN
#
#                                                    url  \
# 0                                                  NaN
# 1    https://www.bestbuy.com/site/insignia-18-cu-ft...
# 3    https://www.bestbuy.com/site/insignia-18-6-cu-...
# 4    https://www.bestbuy.com/site/lg-counter-depth-...
# 15   https://www.bestbuy.com/site/lg-22-5-cu-ft-4-d...
# ..                                                 ...
# 394  https://www.costco.com/allstate-3-years-for-ma...
# 454  https://www.costco.com/ge-17.3-cu.-ft.-frost-f...
# 482  https://www.costco.com/lg-1.8-cu.-ft.-smart-wi...
# 494  https://www.costco.com/samsung-4-piece-gas-kit...
# 499  https://www.costco.com/allstate-3-years-for-ki...
#
#                                            description  \
# 0                                                  NaN
# 1    Specifications Voice Assistant Built-in No Pro...
# 3    Specifications Voice Assistant Built-in No Pro...
# 4    Specifications Voice Assistant Built-in No Pro...
# 15   Specifications Voice Assistant Built-in No Pro...
# ..                                                 ...
# 394  Brand Allstate Product Features 24/7 Support P...
# 454  Brand GE Appliances Color White Defrost Type F...
# 482  Brand LG Capacity 1.8 cu. ft. Connectivity Wi-...
# 494  Brand Samsung Compatible with SmartThings Conn...
# 499  Brand Allstate Product Features 24/7 Support P...
#
#                                                   html  \
# 0                                                  NaN
# 1    <li class="zebra-list-item mt-500 exposed-spec...
# 3    <li class="zebra-list-item mt-500 exposed-spec...
# 4    <li class="zebra-list-item mt-500 exposed-spec...
# 15   <li class="zebra-list-item mt-500 exposed-spec...
# ..                                                 ...
# 394  <div class="product-info-specs body-copy">\n<d...
# 454  <div class="product-info-specs body-copy">\n<d...
# 482  <div class="product-info-specs body-copy">\n<d...
# 494  <div class="product-info-specs body-copy">\n<d...
# 499  <div class="product-info-specs body-copy">\n<d...
#
#                                         normalized_nom  \
# 0                                                  nan
# 1    insignia™ - 18 cu. ft. top-freezer refrigerato...
# 3    insignia™ - 18.6 cu. ft. bottom freezer refrig...
# 4    lg - counter-depth max 25.5 cu. ft. french doo...
# 15   lg - 22.5 cu. ft. 4-door french door-in-door c...
# ..                                                 ...
# 394  allstate 3 years (for major appliances above $...
# 454  ge 17.3 cu. ft. frost free garage ready uprigh...
# 482  lg 1.8 cu. ft. smart wi-fi enabled over-the-ra...
# 494  samsung 4-piece gas kitchen package with count...
# 499  allstate 3 years (for kitchen suites above $4000)
#
#                                 normalized_description  \
# 0
# 1    specifications voice assistant built-in no pro...
# 3    specifications voice assistant built-in no pro...
# 4    specifications voice assistant built-in no pro...
# 15   specifications voice assistant built-in no pro...
# ..                                                 ...
# 394  brand allstate product features 24/7 support p...
# 454  brand ge appliances color white defrost type f...
# 482  brand lg capacity 1.8 cu. ft. connectivity wi-...
# 494  brand samsung compatible with smartthings conn...
# 499  brand allstate product features 24/7 support p...
#
#                                    nom_and_description
# 0                                                 nan
# 1    insignia™ - 18 cu. ft. top-freezer refrigerato...
# 3    insignia™ - 18.6 cu. ft. bottom freezer refrig...
# 4    lg - counter-depth max 25.5 cu. ft. french doo...
# 15   lg - 22.5 cu. ft. 4-door french door-in-door c...
# ..                                                 ...
# 394  allstate 3 years (for major appliances above $...
# 454  ge 17.3 cu. ft. frost free garage ready uprigh...
# 482  lg 1.8 cu. ft. smart wi-fi enabled over-the-ra...
# 494  samsung 4-piece gas kitchen package with count...
# 499  allstate 3 years (for kitchen suites above $40...
#
# [106 rows x 13 columns]
# Erreur : '[nan] not in index'
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10684\3277654592.py:52: FutureWarning: The behavior of Series.idxmin with all-NA values, or any-NA and skipna=False, is deprecated. In a future version this will raise ValueError
#   min_prix_index = df.loc[group, "prix"].idxmin()
# Removed rows:
#                                                    nom     prix      website  \
# 0                                                  nan      NaN          NaN
# 1    Insignia™ - 18 Cu. Ft. Top-Freezer Refrigerato...   649.99  bestbuy.com
# 3    Insignia™ - 18.6 Cu. Ft. Bottom Freezer Refrig...   799.99  bestbuy.com
# 4    LG - Counter-Depth MAX 25.5 Cu. Ft. French Doo...  2999.99  bestbuy.com
# 15   LG - 22.5 Cu. Ft. 4-Door French Door-in-Door C...  3299.99  bestbuy.com
# ..                                                 ...      ...          ...
# 394  Allstate 3 Years (For Major Appliances Above $...   159.99   costco.com
# 454  GE 17.3 cu. ft. Frost Free Garage Ready Uprigh...   829.99   costco.com
# 482  LG 1.8 cu. ft. Smart Wi-Fi Enabled Over-the-Ra...   449.99   costco.com
# 494  Samsung 4-piece GAS Kitchen Package with Count...  4479.96   costco.com
# 499  Allstate 3 Years (For Kitchen Suites Above $4000)   399.99   costco.com
#
#                                                 source         date_scraped  \
# 0                                                  NaN                  NaN
# 1    https://www.bestbuy.com/site/refrigerators/all...  2025-01-31 02:35:21
# 3    https://www.bestbuy.com/site/refrigerators/all...  2025-01-31 02:35:21
# 4    https://www.bestbuy.com/site/refrigerators/all...  2025-01-31 02:35:21
# 15   https://www.bestbuy.com/site/refrigerators/all...  2025-01-31 02:35:21
# ..                                                 ...                  ...
# 394          https://www.costco.com/refrigerators.html  2025-01-31 02:35:21
# 454    https://www.costco.com/freezers-ice-makers.html  2025-01-31 02:35:21
# 482             https://www.costco.com/microwaves.html  2025-01-31 02:35:21
# 494         https://www.costco.com/kitchen-suites.html  2025-01-31 02:35:21
# 499         https://www.costco.com/kitchen-suites.html  2025-01-31 02:35:21
#
#            category promotion  \
# 0               NaN       NaN
# 1     refrigerators       NaN
# 3     refrigerators       NaN
# 4     refrigerators       NaN
# 15    refrigerators       NaN
# ..              ...       ...
# 394   refrigerators       NaN
# 454        freezers       NaN
# 482      microwaves       NaN
# 494  kitchen-suites       NaN
# 499  kitchen-suites       NaN
#
#                                                    url  \
# 0                                                  NaN
# 1    https://www.bestbuy.com/site/insignia-18-cu-ft...
# 3    https://www.bestbuy.com/site/insignia-18-6-cu-...
# 4    https://www.bestbuy.com/site/lg-counter-depth-...
# 15   https://www.bestbuy.com/site/lg-22-5-cu-ft-4-d...
# ..                                                 ...
# 394  https://www.costco.com/allstate-3-years-for-ma...
# 454  https://www.costco.com/ge-17.3-cu.-ft.-frost-f...
# 482  https://www.costco.com/lg-1.8-cu.-ft.-smart-wi...
# 494  https://www.costco.com/samsung-4-piece-gas-kit...
# 499  https://www.costco.com/allstate-3-years-for-ki...
#
#                                            description  \
# 0                                                  NaN
# 1    Specifications Voice Assistant Built-in No Pro...
# 3    Specifications Voice Assistant Built-in No Pro...
# 4    Specifications Voice Assistant Built-in No Pro...
# 15   Specifications Voice Assistant Built-in No Pro...
# ..                                                 ...
# 394  Brand Allstate Product Features 24/7 Support P...
# 454  Brand GE Appliances Color White Defrost Type F...
# 482  Brand LG Capacity 1.8 cu. ft. Connectivity Wi-...
# 494  Brand Samsung Compatible with SmartThings Conn...
# 499  Brand Allstate Product Features 24/7 Support P...
#
#                                                   html  \
# 0                                                  NaN
# 1    <li class="zebra-list-item mt-500 exposed-spec...
# 3    <li class="zebra-list-item mt-500 exposed-spec...
# 4    <li class="zebra-list-item mt-500 exposed-spec...
# 15   <li class="zebra-list-item mt-500 exposed-spec...
# ..                                                 ...
# 394  <div class="product-info-specs body-copy">\n<d...
# 454  <div class="product-info-specs body-copy">\n<d...
# 482  <div class="product-info-specs body-copy">\n<d...
# 494  <div class="product-info-specs body-copy">\n<d...
# 499  <div class="product-info-specs body-copy">\n<d...
#
#                                         normalized_nom  \
# 0                                                  nan
# 1    insignia™ - 18 cu. ft. top-freezer refrigerato...
# 3    insignia™ - 18.6 cu. ft. bottom freezer refrig...
# 4    lg - counter-depth max 25.5 cu. ft. french doo...
# 15   lg - 22.5 cu. ft. 4-door french door-in-door c...
# ..                                                 ...
# 394  allstate 3 years (for major appliances above $...
# 454  ge 17.3 cu. ft. frost free garage ready uprigh...
# 482  lg 1.8 cu. ft. smart wi-fi enabled over-the-ra...
# 494  samsung 4-piece gas kitchen package with count...
# 499  allstate 3 years (for kitchen suites above $4000)
#
#                                 normalized_description  \
# 0
# 1    specifications voice assistant built-in no pro...
# 3    specifications voice assistant built-in no pro...
# 4    specifications voice assistant built-in no pro...
# 15   specifications voice assistant built-in no pro...
# ..                                                 ...
# 394  brand allstate product features 24/7 support p...
# 454  brand ge appliances color white defrost type f...
# 482  brand lg capacity 1.8 cu. ft. connectivity wi-...
# 494  brand samsung compatible with smartthings conn...
# 499  brand allstate product features 24/7 support p...
#
#                                    nom_and_description
# 0                                                 nan
# 1    insignia™ - 18 cu. ft. top-freezer refrigerato...
# 3    insignia™ - 18.6 cu. ft. bottom freezer refrig...
# 4    lg - counter-depth max 25.5 cu. ft. french doo...
# 15   lg - 22.5 cu. ft. 4-door french door-in-door c...
# ..                                                 ...
# 394  allstate 3 years (for major appliances above $...
# 454  ge 17.3 cu. ft. frost free garage ready uprigh...
# 482  lg 1.8 cu. ft. smart wi-fi enabled over-the-ra...
# 494  samsung 4-piece gas kitchen package with count...
# 499  allstate 3 years (for kitchen suites above $40...
#
# [106 rows x 13 columns]
# Erreur : '[nan] not in index'
# Data exported to 'temp2Electromenagerscleaned_data'
# Appended site: https://www.whirlpool.com/kitchen/cooking/cooktops/see-all.html?plp=%3ABest%20Seller%3Acategory%3AKitchenCookingCooktops%3AshowMajorProductsOnly%3Atrue%3AinStock%3Atrue&plpView=grid&currentPage=0
# Add :  https://www.whirlpool.com/kitchen/cooking/cooktops/see-all.html?plp=%3ABest%20Seller%3Acategory%3AKitchenCookingCooktops%3AshowMajorProductsOnly%3Atrue%3AinStock%3Atrue&plpView=grid&currentPage=0
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10684\3277654592.py:52: FutureWarning: The behavior of Series.idxmin with all-NA values, or any-NA and skipna=False, is deprecated. In a future version this will raise ValueError
#   min_prix_index = df.loc[group, "prix"].idxmin()
# Erreur : "None of [Index([34], dtype='int32')] are in the [index]"
# Data exported to 'Electromenagerscleaned_data'
#
# End..
